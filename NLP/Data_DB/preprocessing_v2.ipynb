# %%
import numpy as np
import pandas as pd

DB = pd.read_excel('영양성분DB_가공식품.xlsx')
DB.head()
# Out:
#                   식품코드               식품명 데이터구분코드 데이터구분명  식품기원코드 식품기원명  \
# 0  P101-101000100-0001         33한체다치즈팝콘       P   가공식품       1  가공식품
# 1  P101-101000100-0002      CGV시그니처스위트팝콘       P   가공식품       1  가공식품
# 2  P101-101000100-0003   CGV시그니처카라멜&치즈팝콘       P   가공식품       1  가공식품
# 3  P101-101000100-0004  dardaby커널스슈퍼믹스팝콘       P   가공식품       1  가공식품
# 4  P101-101000100-0005   dardaby커널스씨네마팝콘       P   가공식품       1  가공식품
#
#    식품대분류코드        식품대분류명  대표식품코드   대표식품명  ...      제조사명 수입업체명  유통업체명 수입여부  \
# 0        1  과자류·빵류 또는 떡류    1101  강냉이/팝콘  ...  대한푸드텍(주)  해당없음   해당없음    N
# 1        1  과자류·빵류 또는 떡류    1101  강냉이/팝콘  ...   (주)제이앤이  해당없음   해당없음    N
# 2        1  과자류·빵류 또는 떡류    1101  강냉이/팝콘  ...   (주)제이앤이  해당없음   해당없음    N
# 3        1  과자류·빵류 또는 떡류    1101  강냉이/팝콘  ...   (주)제이앤이  해당없음   해당없음    N
# 4        1  과자류·빵류 또는 떡류    1101  강냉이/팝콘  ...   (주)제이앤이  해당없음   해당없음    N
#
#    원산지국코드 원산지국명 데이터생성방법코드  데이터생성방법명     데이터생성일자    데이터기준일자
# ...

# %%
drink_db = DB[DB['식품대분류코드']==9]

# %%
columns=['식품명', '영양성분함량기준량', '에너지(kcal)', '단백질(g)', '지방(g)', '탄수화물(g)', '당류(g)', '나트륨(mg)',
          '콜레스테롤(mg)', '포화지방산(g)', '트랜스지방산(g)', '식품중량']

clean_drink_db = drink_db[columns]
clean_drink_db.to_excel('Drink_DB.xlsx',index=False)
